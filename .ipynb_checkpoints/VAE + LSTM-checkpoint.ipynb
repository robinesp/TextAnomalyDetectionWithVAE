# %% [markdown]
# # VAE + LSTM for anomaly detection in text

# %%
import pickle
import itertools
import numpy as np
from scipy import spatial
from scipy.stats import norm
import nltk.data
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from nltk.corpus import reuters
from nltk. corpus import gutenberg
from nltk.corpus import brown
from nltk.tokenize import sent_tokenize
from gensim.models import KeyedVectors
from keras.layers import Input, Dense, Lambda, Layer, LSTM, RepeatVector
from keras.callbacks import ModelCheckpoint
from keras.models import Model
from keras.models import load_model
from keras import backend as K
from keras import metrics
from keras import objectives
import matplotlib.pyplot as plt
import sklearn.metrics as skl
import seaborn as sns

nltk.download('punkt')
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Load Text Data

# %%
with open ('drive/Seminar/data/reviews_processed.pickle', 'rb') as f:
    data = pickle.load(f)
print("Total reviews: ", len(data))

data_min = np.array(data).min()
data_max = np.array(data).max()
with open ('drive/Seminar/data/scale_values_lstm.pickle', 'wb') as f:
    pickle.dump({'min':data_min, 'max':data_max}, f)

data_concat = []
for x in data[:50000]:
  data_concat.append(list(itertools.chain.from_iterable(x)))
  
data_array = np.array(data_concat)
    
data_array = np.interp(data_array, (data_array.min(), data_array.max()), (0, 1))

np.random.shuffle(data_array)
data_array = data_array.reshape(-1,10,300)

train = data_array[:40000]
test = data_array[40000:50000]
# Out:
# Total reviews:  91798

# %% [markdown]
#  ## Variational Autoencoder with LSTM

# %%
batch_size = 500 #(for training)
timesteps = 10
original_dim = 300
latent_dim = 200
intermediate_dim = 250
epochs = 100
epsilon_std = 1.0

x = Input(batch_shape=(batch_size, timesteps, original_dim))
h = LSTM(intermediate_dim)(x)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)
      
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,
                              stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon
  
def xent_loss(y_true, y_pred):
  return original_dim * metrics.binary_crossentropy(K.flatten(y_true), K.flatten(y_pred))

def mse_loss(y_true, y_pred):
  return original_dim * metrics.mse(K.flatten(y_true), K.flatten(y_pred))

def kl_loss(y_true, y_pred):
  return - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)

def vae_loss(y_true, y_pred):
  mse_loss = original_dim * metrics.mse(K.flatten(y_true), K.flatten(y_pred))
  kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
  return K.mean(mse_loss + kl_loss)

# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# we instantiate these layers separately so as to reuse them later
decoder_h = LSTM(intermediate_dim, return_sequences=True)
decoder_mean = LSTM(original_dim, activation='sigmoid', return_sequences=True)

h_decoded = RepeatVector(timesteps)(z)
h_decoded = decoder_h(h_decoded)
x_decoded_mean = decoder_mean(h_decoded)

vae = Model(x, [x_decoded_mean])
vae.compile(optimizer='rmsprop', loss=[vae_loss], metrics=[xent_loss, mse_loss, kl_loss])
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (500, 10, 300)       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (500, 250)           551000      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (500, 200)           50200       lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (500, 200)           50200       lstm_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (500, 200)           0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (500, 10, 200)       0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (500, 10, 250)       451000      repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (500, 10, 300)       661200      lstm_2[0][0]
# ==================================================================================================
# Total params: 1,763,600
# Trainable params: 1,763,600
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#checkpoint
cp = [ModelCheckpoint(filepath="drive/Seminar/models/vae_lstm.h5", verbose=1, save_best_only=True)]

#train
history = vae.fit(train, train,
        shuffle=True,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(test, test),
        callbacks=cp)

#save weights, model and history to file
vae.save_weights('drive/Seminar/models/vae_lstm_weights.hdf5')

with open ('drive/Seminar/models/vae_lstm.json', 'w') as json_file:
    json_file.write(vae.to_json())

with open ('drive/Seminar/models/history_lstm.pickle', 'wb') as f:
    pickle.dump(history, f)
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 17s 436us/step - loss: 2.7715 - xent_loss: 211.2395 - mse_loss: 2.3988 - kl_loss: 0.3727 - val_loss: 1.5357 - val_xent_loss: 209.3328 - val_mse_loss: 1.5306 - val_kl_loss: 0.0051
#
# Epoch 00001: val_loss improved from inf to 1.53567, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 2/100
# 40000/40000 [==============================] - 11s 280us/step - loss: 1.0688 - xent_loss: 208.3465 - mse_loss: 1.0672 - kl_loss: 0.0017 - val_loss: 0.8379 - val_xent_loss: 207.8703 - val_mse_loss: 0.8378 - val_kl_loss: 1.4032e-04
#
# Epoch 00002: val_loss improved from 1.53567 to 0.83791, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 3/100
# 40000/40000 [==============================] - 11s 277us/step - loss: 0.8015 - xent_loss: 207.7971 - mse_loss: 0.8014 - kl_loss: 5.7390e-05 - val_loss: 0.7886 - val_xent_loss: 207.7715 - val_mse_loss: 0.7885 - val_kl_loss: 6.0834e-05
#
# Epoch 00003: val_loss improved from 0.83791 to 0.78856, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 4/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7757 - xent_loss: 207.7454 - mse_loss: 0.7757 - kl_loss: 4.8089e-05 - val_loss: 0.7721 - val_xent_loss: 207.7385 - val_mse_loss: 0.7721 - val_kl_loss: 5.5489e-05
#
# Epoch 00004: val_loss improved from 0.78856 to 0.77211, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 5/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7637 - xent_loss: 207.7212 - mse_loss: 0.7636 - kl_loss: 4.2621e-05 - val_loss: 0.7630 - val_xent_loss: 207.7202 - val_mse_loss: 0.7629 - val_kl_loss: 4.8347e-05
#
# Epoch 00005: val_loss improved from 0.77211 to 0.76297, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 6/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7578 - xent_loss: 207.7093 - mse_loss: 0.7577 - kl_loss: 4.0925e-05 - val_loss: 0.7488 - val_xent_loss: 207.6918 - val_mse_loss: 0.7487 - val_kl_loss: 3.4571e-05
#
# Epoch 00006: val_loss improved from 0.76297 to 0.74877, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 7/100
# 40000/40000 [==============================] - 12s 288us/step - loss: 0.7523 - xent_loss: 207.6983 - mse_loss: 0.7522 - kl_loss: 3.9070e-05 - val_loss: 0.7478 - val_xent_loss: 207.6898 - val_mse_loss: 0.7478 - val_kl_loss: 3.6414e-05
#
# Epoch 00007: val_loss improved from 0.74877 to 0.74780, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 8/100
# 40000/40000 [==============================] - 12s 292us/step - loss: 0.7482 - xent_loss: 207.6902 - mse_loss: 0.7482 - kl_loss: 3.8196e-05 - val_loss: 0.7437 - val_xent_loss: 207.6816 - val_mse_loss: 0.7436 - val_kl_loss: 3.6768e-05
#
# Epoch 00008: val_loss improved from 0.74780 to 0.74367, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 9/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7452 - xent_loss: 207.6840 - mse_loss: 0.7451 - kl_loss: 3.8277e-05 - val_loss: 0.7413 - val_xent_loss: 207.6768 - val_mse_loss: 0.7412 - val_kl_loss: 3.2305e-05
#
# Epoch 00009: val_loss improved from 0.74367 to 0.74127, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 10/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7423 - xent_loss: 207.6784 - mse_loss: 0.7423 - kl_loss: 3.7356e-05 - val_loss: 0.7411 - val_xent_loss: 207.6764 - val_mse_loss: 0.7411 - val_kl_loss: 3.4661e-05
#
# Epoch 00010: val_loss improved from 0.74127 to 0.74109, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 11/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7405 - xent_loss: 207.6748 - mse_loss: 0.7405 - kl_loss: 3.7278e-05 - val_loss: 0.7427 - val_xent_loss: 207.6796 - val_mse_loss: 0.7427 - val_kl_loss: 4.6531e-05
#
# Epoch 00011: val_loss did not improve from 0.74109
# Epoch 12/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7389 - xent_loss: 207.6714 - mse_loss: 0.7388 - kl_loss: 3.7574e-05 - val_loss: 0.7350 - val_xent_loss: 207.6643 - val_mse_loss: 0.7350 - val_kl_loss: 3.1544e-05
#
# Epoch 00012: val_loss improved from 0.74109 to 0.73505, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 13/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7375 - xent_loss: 207.6686 - mse_loss: 0.7374 - kl_loss: 3.7265e-05 - val_loss: 0.7370 - val_xent_loss: 207.6682 - val_mse_loss: 0.7369 - val_kl_loss: 4.1987e-05
#
# Epoch 00013: val_loss did not improve from 0.73505
# Epoch 14/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7366 - xent_loss: 207.6668 - mse_loss: 0.7365 - kl_loss: 3.7118e-05 - val_loss: 0.7360 - val_xent_loss: 207.6663 - val_mse_loss: 0.7360 - val_kl_loss: 3.4513e-05
#
# Epoch 00014: val_loss did not improve from 0.73505
# Epoch 15/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7359 - xent_loss: 207.6655 - mse_loss: 0.7359 - kl_loss: 3.7205e-05 - val_loss: 0.7367 - val_xent_loss: 207.6676 - val_mse_loss: 0.7367 - val_kl_loss: 4.0794e-05
#
# Epoch 00015: val_loss did not improve from 0.73505
# Epoch 16/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7351 - xent_loss: 207.6639 - mse_loss: 0.7351 - kl_loss: 3.6463e-05 - val_loss: 0.7350 - val_xent_loss: 207.6641 - val_mse_loss: 0.7349 - val_kl_loss: 3.8147e-05
#
# Epoch 00016: val_loss improved from 0.73505 to 0.73496, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 17/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7344 - xent_loss: 207.6624 - mse_loss: 0.7343 - kl_loss: 3.7307e-05 - val_loss: 0.7355 - val_xent_loss: 207.6651 - val_mse_loss: 0.7354 - val_kl_loss: 4.3554e-05
#
# Epoch 00017: val_loss did not improve from 0.73496
# Epoch 18/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7338 - xent_loss: 207.6613 - mse_loss: 0.7338 - kl_loss: 3.7090e-05 - val_loss: 0.7331 - val_xent_loss: 207.6604 - val_mse_loss: 0.7331 - val_kl_loss: 3.8563e-05
#
# Epoch 00018: val_loss improved from 0.73496 to 0.73309, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 19/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7332 - xent_loss: 207.6600 - mse_loss: 0.7332 - kl_loss: 3.6866e-05 - val_loss: 0.7340 - val_xent_loss: 207.6621 - val_mse_loss: 0.7339 - val_kl_loss: 4.6421e-05
#
# Epoch 00019: val_loss did not improve from 0.73309
# Epoch 20/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7327 - xent_loss: 207.6589 - mse_loss: 0.7326 - kl_loss: 3.6746e-05 - val_loss: 0.7297 - val_xent_loss: 207.6537 - val_mse_loss: 0.7297 - val_kl_loss: 3.1499e-05
#
# Epoch 00020: val_loss improved from 0.73309 to 0.72975, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 21/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7323 - xent_loss: 207.6582 - mse_loss: 0.7323 - kl_loss: 3.6762e-05 - val_loss: 0.7325 - val_xent_loss: 207.6591 - val_mse_loss: 0.7324 - val_kl_loss: 3.7015e-05
#
# Epoch 00021: val_loss did not improve from 0.72975
# Epoch 22/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7320 - xent_loss: 207.6577 - mse_loss: 0.7320 - kl_loss: 3.6959e-05 - val_loss: 0.7302 - val_xent_loss: 207.6545 - val_mse_loss: 0.7301 - val_kl_loss: 3.2520e-05
#
# Epoch 00022: val_loss did not improve from 0.72975
# Epoch 23/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7315 - xent_loss: 207.6565 - mse_loss: 0.7314 - kl_loss: 3.6366e-05 - val_loss: 0.7309 - val_xent_loss: 207.6560 - val_mse_loss: 0.7309 - val_kl_loss: 3.6400e-05
#
# Epoch 00023: val_loss did not improve from 0.72975
# Epoch 24/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7315 - xent_loss: 207.6565 - mse_loss: 0.7314 - kl_loss: 3.6939e-05 - val_loss: 0.7311 - val_xent_loss: 207.6564 - val_mse_loss: 0.7311 - val_kl_loss: 3.5065e-05
#
# Epoch 00024: val_loss did not improve from 0.72975
# Epoch 25/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7309 - xent_loss: 207.6554 - mse_loss: 0.7308 - kl_loss: 3.6739e-05 - val_loss: 0.7299 - val_xent_loss: 207.6540 - val_mse_loss: 0.7299 - val_kl_loss: 3.3816e-05
#
# Epoch 00025: val_loss did not improve from 0.72975
# Epoch 26/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7307 - xent_loss: 207.6549 - mse_loss: 0.7306 - kl_loss: 3.6833e-05 - val_loss: 0.7304 - val_xent_loss: 207.6549 - val_mse_loss: 0.7303 - val_kl_loss: 3.5555e-05
#
# Epoch 00026: val_loss did not improve from 0.72975
# Epoch 27/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7303 - xent_loss: 207.6543 - mse_loss: 0.7303 - kl_loss: 3.6729e-05 - val_loss: 0.7318 - val_xent_loss: 207.6579 - val_mse_loss: 0.7318 - val_kl_loss: 3.9207e-05
#
# Epoch 00027: val_loss did not improve from 0.72975
# Epoch 28/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7301 - xent_loss: 207.6538 - mse_loss: 0.7300 - kl_loss: 3.6985e-05 - val_loss: 0.7304 - val_xent_loss: 207.6550 - val_mse_loss: 0.7304 - val_kl_loss: 3.4327e-05
#
# Epoch 00028: val_loss did not improve from 0.72975
# Epoch 29/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7295 - xent_loss: 207.6526 - mse_loss: 0.7295 - kl_loss: 3.6845e-05 - val_loss: 0.7285 - val_xent_loss: 207.6512 - val_mse_loss: 0.7285 - val_kl_loss: 2.8077e-05
#
# Epoch 00029: val_loss improved from 0.72975 to 0.72850, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 30/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7296 - xent_loss: 207.6528 - mse_loss: 0.7295 - kl_loss: 3.6935e-05 - val_loss: 0.7283 - val_xent_loss: 207.6507 - val_mse_loss: 0.7283 - val_kl_loss: 3.7659e-05
#
# Epoch 00030: val_loss improved from 0.72850 to 0.72829, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 31/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7294 - xent_loss: 207.6525 - mse_loss: 0.7294 - kl_loss: 3.6838e-05 - val_loss: 0.7293 - val_xent_loss: 207.6528 - val_mse_loss: 0.7293 - val_kl_loss: 4.0429e-05
#
# Epoch 00031: val_loss did not improve from 0.72829
# Epoch 32/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7293 - xent_loss: 207.6522 - mse_loss: 0.7293 - kl_loss: 3.7012e-05 - val_loss: 0.7296 - val_xent_loss: 207.6535 - val_mse_loss: 0.7296 - val_kl_loss: 3.8200e-05
#
# Epoch 00032: val_loss did not improve from 0.72829
# Epoch 33/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7294 - xent_loss: 207.6524 - mse_loss: 0.7294 - kl_loss: 3.6700e-05 - val_loss: 0.7294 - val_xent_loss: 207.6529 - val_mse_loss: 0.7293 - val_kl_loss: 3.7262e-05
#
# Epoch 00033: val_loss did not improve from 0.72829
# Epoch 34/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7290 - xent_loss: 207.6517 - mse_loss: 0.7290 - kl_loss: 3.6992e-05 - val_loss: 0.7297 - val_xent_loss: 207.6536 - val_mse_loss: 0.7297 - val_kl_loss: 4.1288e-05
#
# Epoch 00034: val_loss did not improve from 0.72829
# Epoch 35/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7290 - xent_loss: 207.6517 - mse_loss: 0.7290 - kl_loss: 3.7184e-05 - val_loss: 0.7293 - val_xent_loss: 207.6528 - val_mse_loss: 0.7293 - val_kl_loss: 4.0421e-05
#
# Epoch 00035: val_loss did not improve from 0.72829
# Epoch 36/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7290 - xent_loss: 207.6516 - mse_loss: 0.7290 - kl_loss: 3.7011e-05 - val_loss: 0.7289 - val_xent_loss: 207.6520 - val_mse_loss: 0.7289 - val_kl_loss: 4.0992e-05
#
# Epoch 00036: val_loss did not improve from 0.72829
# Epoch 37/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7289 - xent_loss: 207.6515 - mse_loss: 0.7289 - kl_loss: 3.7011e-05 - val_loss: 0.7275 - val_xent_loss: 207.6492 - val_mse_loss: 0.7275 - val_kl_loss: 3.9139e-05
#
# Epoch 00037: val_loss improved from 0.72829 to 0.72754, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 38/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7287 - xent_loss: 207.6510 - mse_loss: 0.7287 - kl_loss: 3.6984e-05 - val_loss: 0.7291 - val_xent_loss: 207.6524 - val_mse_loss: 0.7291 - val_kl_loss: 3.6794e-05
#
# Epoch 00038: val_loss did not improve from 0.72754
# Epoch 39/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7287 - xent_loss: 207.6510 - mse_loss: 0.7286 - kl_loss: 3.7070e-05 - val_loss: 0.7285 - val_xent_loss: 207.6513 - val_mse_loss: 0.7285 - val_kl_loss: 3.4519e-05
#
# Epoch 00039: val_loss did not improve from 0.72754
# Epoch 40/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7285 - xent_loss: 207.6507 - mse_loss: 0.7285 - kl_loss: 3.6790e-05 - val_loss: 0.7272 - val_xent_loss: 207.6486 - val_mse_loss: 0.7272 - val_kl_loss: 3.6555e-05
#
# Epoch 00040: val_loss improved from 0.72754 to 0.72719, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 41/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7285 - xent_loss: 207.6507 - mse_loss: 0.7285 - kl_loss: 3.7416e-05 - val_loss: 0.7285 - val_xent_loss: 207.6511 - val_mse_loss: 0.7284 - val_kl_loss: 3.5844e-05
#
# Epoch 00041: val_loss did not improve from 0.72719
# Epoch 42/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7285 - xent_loss: 207.6505 - mse_loss: 0.7284 - kl_loss: 3.7066e-05 - val_loss: 0.7278 - val_xent_loss: 207.6497 - val_mse_loss: 0.7277 - val_kl_loss: 4.1075e-05
#
# Epoch 00042: val_loss did not improve from 0.72719
# Epoch 43/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7286 - xent_loss: 207.6508 - mse_loss: 0.7285 - kl_loss: 3.7263e-05 - val_loss: 0.7288 - val_xent_loss: 207.6517 - val_mse_loss: 0.7287 - val_kl_loss: 3.9346e-05
#
# Epoch 00043: val_loss did not improve from 0.72719
# Epoch 44/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7285 - xent_loss: 207.6506 - mse_loss: 0.7285 - kl_loss: 3.7321e-05 - val_loss: 0.7279 - val_xent_loss: 207.6500 - val_mse_loss: 0.7279 - val_kl_loss: 3.7763e-05
#
# Epoch 00044: val_loss did not improve from 0.72719
# Epoch 45/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7285 - xent_loss: 207.6506 - mse_loss: 0.7285 - kl_loss: 3.7104e-05 - val_loss: 0.7281 - val_xent_loss: 207.6505 - val_mse_loss: 0.7281 - val_kl_loss: 3.6733e-05
#
# Epoch 00045: val_loss did not improve from 0.72719
# Epoch 46/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7283 - xent_loss: 207.6503 - mse_loss: 0.7283 - kl_loss: 3.7236e-05 - val_loss: 0.7263 - val_xent_loss: 207.6468 - val_mse_loss: 0.7263 - val_kl_loss: 3.3416e-05
#
# Epoch 00046: val_loss improved from 0.72719 to 0.72634, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 47/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7284 - xent_loss: 207.6504 - mse_loss: 0.7284 - kl_loss: 3.7254e-05 - val_loss: 0.7286 - val_xent_loss: 207.6514 - val_mse_loss: 0.7286 - val_kl_loss: 3.7253e-05
#
# Epoch 00047: val_loss did not improve from 0.72634
# Epoch 48/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7283 - xent_loss: 207.6501 - mse_loss: 0.7282 - kl_loss: 3.7223e-05 - val_loss: 0.7295 - val_xent_loss: 207.6531 - val_mse_loss: 0.7294 - val_kl_loss: 3.9940e-05
#
# Epoch 00048: val_loss did not improve from 0.72634
# Epoch 49/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7283 - xent_loss: 207.6502 - mse_loss: 0.7282 - kl_loss: 3.7176e-05 - val_loss: 0.7277 - val_xent_loss: 207.6496 - val_mse_loss: 0.7277 - val_kl_loss: 3.5589e-05
#
# Epoch 00049: val_loss did not improve from 0.72634
# Epoch 50/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7283 - xent_loss: 207.6502 - mse_loss: 0.7283 - kl_loss: 3.7298e-05 - val_loss: 0.7265 - val_xent_loss: 207.6472 - val_mse_loss: 0.7265 - val_kl_loss: 3.6555e-05
#
# Epoch 00050: val_loss did not improve from 0.72634
# Epoch 51/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7282 - xent_loss: 207.6500 - mse_loss: 0.7282 - kl_loss: 3.7308e-05 - val_loss: 0.7283 - val_xent_loss: 207.6508 - val_mse_loss: 0.7283 - val_kl_loss: 3.5499e-05
#
# Epoch 00051: val_loss did not improve from 0.72634
# Epoch 52/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7282 - xent_loss: 207.6501 - mse_loss: 0.7282 - kl_loss: 3.7382e-05 - val_loss: 0.7280 - val_xent_loss: 207.6501 - val_mse_loss: 0.7279 - val_kl_loss: 3.8595e-05
#
# Epoch 00052: val_loss did not improve from 0.72634
# Epoch 53/100
# 40000/40000 [==============================] - 12s 290us/step - loss: 0.7282 - xent_loss: 207.6500 - mse_loss: 0.7282 - kl_loss: 3.7067e-05 - val_loss: 0.7279 - val_xent_loss: 207.6499 - val_mse_loss: 0.7278 - val_kl_loss: 3.6669e-05
#
# Epoch 00053: val_loss did not improve from 0.72634
# Epoch 54/100
# 40000/40000 [==============================] - 11s 287us/step - loss: 0.7279 - xent_loss: 207.6494 - mse_loss: 0.7279 - kl_loss: 3.7432e-05 - val_loss: 0.7280 - val_xent_loss: 207.6501 - val_mse_loss: 0.7279 - val_kl_loss: 3.8520e-05
#
# Epoch 00054: val_loss did not improve from 0.72634
# Epoch 55/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7280 - xent_loss: 207.6495 - mse_loss: 0.7279 - kl_loss: 3.7533e-05 - val_loss: 0.7279 - val_xent_loss: 207.6500 - val_mse_loss: 0.7279 - val_kl_loss: 3.7672e-05
#
# Epoch 00055: val_loss did not improve from 0.72634
# Epoch 56/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7280 - xent_loss: 207.6496 - mse_loss: 0.7280 - kl_loss: 3.7591e-05 - val_loss: 0.7273 - val_xent_loss: 207.6487 - val_mse_loss: 0.7273 - val_kl_loss: 3.6847e-05
#
# Epoch 00056: val_loss did not improve from 0.72634
# Epoch 57/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7280 - xent_loss: 207.6495 - mse_loss: 0.7279 - kl_loss: 3.7299e-05 - val_loss: 0.7267 - val_xent_loss: 207.6476 - val_mse_loss: 0.7267 - val_kl_loss: 3.8430e-05
#
# Epoch 00057: val_loss did not improve from 0.72634
# Epoch 58/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7280 - xent_loss: 207.6495 - mse_loss: 0.7279 - kl_loss: 3.7359e-05 - val_loss: 0.7280 - val_xent_loss: 207.6502 - val_mse_loss: 0.7280 - val_kl_loss: 3.7658e-05
#
# Epoch 00058: val_loss did not improve from 0.72634
# Epoch 59/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7279 - xent_loss: 207.6494 - mse_loss: 0.7279 - kl_loss: 3.7486e-05 - val_loss: 0.7288 - val_xent_loss: 207.6519 - val_mse_loss: 0.7288 - val_kl_loss: 3.8435e-05
#
# Epoch 00059: val_loss did not improve from 0.72634
# Epoch 60/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7279 - xent_loss: 207.6493 - mse_loss: 0.7278 - kl_loss: 3.7399e-05 - val_loss: 0.7267 - val_xent_loss: 207.6476 - val_mse_loss: 0.7267 - val_kl_loss: 3.8389e-05
#
# Epoch 00060: val_loss did not improve from 0.72634
# Epoch 61/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7280 - xent_loss: 207.6495 - mse_loss: 0.7279 - kl_loss: 3.7372e-05 - val_loss: 0.7275 - val_xent_loss: 207.6491 - val_mse_loss: 0.7274 - val_kl_loss: 3.6276e-05
#
# Epoch 00061: val_loss did not improve from 0.72634
# Epoch 62/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7278 - xent_loss: 207.6492 - mse_loss: 0.7277 - kl_loss: 3.7404e-05 - val_loss: 0.7275 - val_xent_loss: 207.6492 - val_mse_loss: 0.7275 - val_kl_loss: 4.0239e-05
#
# Epoch 00062: val_loss did not improve from 0.72634
# Epoch 63/100
# 40000/40000 [==============================] - 11s 277us/step - loss: 0.7278 - xent_loss: 207.6492 - mse_loss: 0.7278 - kl_loss: 3.7425e-05 - val_loss: 0.7268 - val_xent_loss: 207.6478 - val_mse_loss: 0.7268 - val_kl_loss: 3.7731e-05
#
# Epoch 00063: val_loss did not improve from 0.72634
# Epoch 64/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7277 - xent_loss: 207.6491 - mse_loss: 0.7277 - kl_loss: 3.7450e-05 - val_loss: 0.7281 - val_xent_loss: 207.6504 - val_mse_loss: 0.7281 - val_kl_loss: 3.7719e-05
#
# Epoch 00064: val_loss did not improve from 0.72634
# Epoch 65/100
# 40000/40000 [==============================] - 11s 276us/step - loss: 0.7278 - xent_loss: 207.6492 - mse_loss: 0.7277 - kl_loss: 3.7435e-05 - val_loss: 0.7280 - val_xent_loss: 207.6501 - val_mse_loss: 0.7279 - val_kl_loss: 3.7617e-05
#
# Epoch 00065: val_loss did not improve from 0.72634
# Epoch 66/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7277 - xent_loss: 207.6490 - mse_loss: 0.7277 - kl_loss: 3.7570e-05 - val_loss: 0.7272 - val_xent_loss: 207.6485 - val_mse_loss: 0.7271 - val_kl_loss: 3.8138e-05
#
# Epoch 00066: val_loss did not improve from 0.72634
# Epoch 67/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7277 - xent_loss: 207.6489 - mse_loss: 0.7276 - kl_loss: 3.7542e-05 - val_loss: 0.7268 - val_xent_loss: 207.6477 - val_mse_loss: 0.7267 - val_kl_loss: 3.8266e-05
#
# Epoch 00067: val_loss did not improve from 0.72634
# Epoch 68/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7277 - xent_loss: 207.6490 - mse_loss: 0.7276 - kl_loss: 3.7451e-05 - val_loss: 0.7278 - val_xent_loss: 207.6497 - val_mse_loss: 0.7277 - val_kl_loss: 3.8247e-05
#
# Epoch 00068: val_loss did not improve from 0.72634
# Epoch 69/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7278 - xent_loss: 207.6491 - mse_loss: 0.7277 - kl_loss: 3.7398e-05 - val_loss: 0.7280 - val_xent_loss: 207.6501 - val_mse_loss: 0.7279 - val_kl_loss: 3.9991e-05
#
# Epoch 00069: val_loss did not improve from 0.72634
# Epoch 70/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7276 - xent_loss: 207.6488 - mse_loss: 0.7275 - kl_loss: 3.7384e-05 - val_loss: 0.7281 - val_xent_loss: 207.6503 - val_mse_loss: 0.7280 - val_kl_loss: 3.8958e-05
#
# Epoch 00070: val_loss did not improve from 0.72634
# Epoch 71/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7276 - xent_loss: 207.6489 - mse_loss: 0.7276 - kl_loss: 3.7613e-05 - val_loss: 0.7266 - val_xent_loss: 207.6475 - val_mse_loss: 0.7266 - val_kl_loss: 3.8750e-05
#
# Epoch 00071: val_loss did not improve from 0.72634
# Epoch 72/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7276 - xent_loss: 207.6488 - mse_loss: 0.7275 - kl_loss: 3.7424e-05 - val_loss: 0.7262 - val_xent_loss: 207.6466 - val_mse_loss: 0.7262 - val_kl_loss: 3.7558e-05
#
# Epoch 00072: val_loss improved from 0.72634 to 0.72623, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 73/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7274 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7504e-05 - val_loss: 0.7265 - val_xent_loss: 207.6472 - val_mse_loss: 0.7265 - val_kl_loss: 3.8741e-05
#
# Epoch 00073: val_loss did not improve from 0.72623
# Epoch 74/100
# 40000/40000 [==============================] - 11s 274us/step - loss: 0.7275 - xent_loss: 207.6486 - mse_loss: 0.7275 - kl_loss: 3.7558e-05 - val_loss: 0.7278 - val_xent_loss: 207.6499 - val_mse_loss: 0.7278 - val_kl_loss: 3.8563e-05
#
# Epoch 00074: val_loss did not improve from 0.72623
# Epoch 75/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7274 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7512e-05 - val_loss: 0.7276 - val_xent_loss: 207.6493 - val_mse_loss: 0.7275 - val_kl_loss: 3.7654e-05
#
# Epoch 00075: val_loss did not improve from 0.72623
# Epoch 76/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7275 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7578e-05 - val_loss: 0.7268 - val_xent_loss: 207.6477 - val_mse_loss: 0.7267 - val_kl_loss: 3.8430e-05
#
# Epoch 00076: val_loss did not improve from 0.72623
# Epoch 77/100
# 40000/40000 [==============================] - 11s 273us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7526e-05 - val_loss: 0.7264 - val_xent_loss: 207.6469 - val_mse_loss: 0.7263 - val_kl_loss: 3.8983e-05
#
# Epoch 00077: val_loss did not improve from 0.72623
# Epoch 78/100
# 40000/40000 [==============================] - 14s 354us/step - loss: 0.7275 - xent_loss: 207.6486 - mse_loss: 0.7274 - kl_loss: 3.7468e-05 - val_loss: 0.7268 - val_xent_loss: 207.6478 - val_mse_loss: 0.7268 - val_kl_loss: 4.0232e-05
#
# Epoch 00078: val_loss did not improve from 0.72623
# Epoch 79/100
# 40000/40000 [==============================] - 13s 329us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7428e-05 - val_loss: 0.7271 - val_xent_loss: 207.6483 - val_mse_loss: 0.7270 - val_kl_loss: 3.8026e-05
#
# Epoch 00079: val_loss did not improve from 0.72623
# Epoch 80/100
# 40000/40000 [==============================] - 13s 328us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7540e-05 - val_loss: 0.7259 - val_xent_loss: 207.6460 - val_mse_loss: 0.7259 - val_kl_loss: 3.7263e-05
#
# Epoch 00080: val_loss improved from 0.72623 to 0.72591, saving model to drive/Seminar/models/vae_lstm.h5
# Epoch 81/100
# 40000/40000 [==============================] - 13s 327us/step - loss: 0.7274 - xent_loss: 207.6483 - mse_loss: 0.7273 - kl_loss: 3.7532e-05 - val_loss: 0.7283 - val_xent_loss: 207.6508 - val_mse_loss: 0.7283 - val_kl_loss: 3.7086e-05
#
# Epoch 00081: val_loss did not improve from 0.72591
# Epoch 82/100
# 40000/40000 [==============================] - 13s 328us/step - loss: 0.7275 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7374e-05 - val_loss: 0.7281 - val_xent_loss: 207.6503 - val_mse_loss: 0.7280 - val_kl_loss: 3.7611e-05
#
# Epoch 00082: val_loss did not improve from 0.72591
# Epoch 83/100
# 40000/40000 [==============================] - 13s 328us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7529e-05 - val_loss: 0.7268 - val_xent_loss: 207.6478 - val_mse_loss: 0.7268 - val_kl_loss: 3.8032e-05
#
# Epoch 00083: val_loss did not improve from 0.72591
# Epoch 84/100
# 40000/40000 [==============================] - 13s 329us/step - loss: 0.7274 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7612e-05 - val_loss: 0.7263 - val_xent_loss: 207.6467 - val_mse_loss: 0.7263 - val_kl_loss: 3.6955e-05
#
# Epoch 00084: val_loss did not improve from 0.72591
# Epoch 85/100
# 40000/40000 [==============================] - 11s 275us/step - loss: 0.7274 - xent_loss: 207.6483 - mse_loss: 0.7273 - kl_loss: 3.7474e-05 - val_loss: 0.7284 - val_xent_loss: 207.6509 - val_mse_loss: 0.7283 - val_kl_loss: 3.8183e-05
#
# Epoch 00085: val_loss did not improve from 0.72591
# Epoch 86/100
# 40000/40000 [==============================] - 11s 269us/step - loss: 0.7273 - xent_loss: 207.6482 - mse_loss: 0.7273 - kl_loss: 3.7533e-05 - val_loss: 0.7280 - val_xent_loss: 207.6502 - val_mse_loss: 0.7280 - val_kl_loss: 3.8006e-05
#
# Epoch 00086: val_loss did not improve from 0.72591
# Epoch 87/100
# 40000/40000 [==============================] - 11s 268us/step - loss: 0.7274 - xent_loss: 207.6483 - mse_loss: 0.7273 - kl_loss: 3.7532e-05 - val_loss: 0.7278 - val_xent_loss: 207.6498 - val_mse_loss: 0.7278 - val_kl_loss: 3.7503e-05
#
# Epoch 00087: val_loss did not improve from 0.72591
# Epoch 88/100
# 40000/40000 [==============================] - 11s 272us/step - loss: 0.7272 - xent_loss: 207.6480 - mse_loss: 0.7272 - kl_loss: 3.7549e-05 - val_loss: 0.7273 - val_xent_loss: 207.6488 - val_mse_loss: 0.7273 - val_kl_loss: 3.7195e-05
#
# Epoch 00088: val_loss did not improve from 0.72591
# Epoch 89/100
# 40000/40000 [==============================] - 11s 271us/step - loss: 0.7272 - xent_loss: 207.6479 - mse_loss: 0.7271 - kl_loss: 3.7423e-05 - val_loss: 0.7281 - val_xent_loss: 207.6503 - val_mse_loss: 0.7280 - val_kl_loss: 3.8077e-05
#
# Epoch 00089: val_loss did not improve from 0.72591
# Epoch 90/100
# 40000/40000 [==============================] - 11s 270us/step - loss: 0.7272 - xent_loss: 207.6480 - mse_loss: 0.7271 - kl_loss: 3.7428e-05 - val_loss: 0.7265 - val_xent_loss: 207.6472 - val_mse_loss: 0.7265 - val_kl_loss: 3.7770e-05
#
# Epoch 00090: val_loss did not improve from 0.72591
# Epoch 91/100
# 40000/40000 [==============================] - 11s 270us/step - loss: 0.7272 - xent_loss: 207.6479 - mse_loss: 0.7271 - kl_loss: 3.7500e-05 - val_loss: 0.7266 - val_xent_loss: 207.6473 - val_mse_loss: 0.7265 - val_kl_loss: 3.7563e-05
#
# Epoch 00091: val_loss did not improve from 0.72591
# Epoch 92/100
# 40000/40000 [==============================] - 11s 268us/step - loss: 0.7271 - xent_loss: 207.6479 - mse_loss: 0.7271 - kl_loss: 3.7606e-05 - val_loss: 0.7269 - val_xent_loss: 207.6480 - val_mse_loss: 0.7268 - val_kl_loss: 3.7503e-05
#
# Epoch 00092: val_loss did not improve from 0.72591
# Epoch 93/100
# 40000/40000 [==============================] - 11s 270us/step - loss: 0.7271 - xent_loss: 207.6478 - mse_loss: 0.7271 - kl_loss: 3.7599e-05 - val_loss: 0.7271 - val_xent_loss: 207.6483 - val_mse_loss: 0.7270 - val_kl_loss: 3.8018e-05
#
# Epoch 00093: val_loss did not improve from 0.72591
# Epoch 94/100
# 40000/40000 [==============================] - 11s 271us/step - loss: 0.7271 - xent_loss: 207.6479 - mse_loss: 0.7271 - kl_loss: 3.7505e-05 - val_loss: 0.7269 - val_xent_loss: 207.6479 - val_mse_loss: 0.7268 - val_kl_loss: 3.8327e-05
#
# Epoch 00094: val_loss did not improve from 0.72591
# Epoch 95/100
# 40000/40000 [==============================] - 11s 269us/step - loss: 0.7272 - xent_loss: 207.6479 - mse_loss: 0.7271 - kl_loss: 3.7535e-05 - val_loss: 0.7270 - val_xent_loss: 207.6482 - val_mse_loss: 0.7270 - val_kl_loss: 3.8095e-05
#
# Epoch 00095: val_loss did not improve from 0.72591
# Epoch 96/100
# 40000/40000 [==============================] - 11s 268us/step - loss: 0.7271 - xent_loss: 207.6477 - mse_loss: 0.7270 - kl_loss: 3.7493e-05 - val_loss: 0.7276 - val_xent_loss: 207.6493 - val_mse_loss: 0.7275 - val_kl_loss: 3.8039e-05
#
# Epoch 00096: val_loss did not improve from 0.72591
# Epoch 97/100
# 40000/40000 [==============================] - 11s 269us/step - loss: 0.7273 - xent_loss: 207.6483 - mse_loss: 0.7273 - kl_loss: 3.7611e-05 - val_loss: 0.7274 - val_xent_loss: 207.6490 - val_mse_loss: 0.7274 - val_kl_loss: 3.7744e-05
#
# Epoch 00097: val_loss did not improve from 0.72591
# Epoch 98/100
# 40000/40000 [==============================] - 11s 269us/step - loss: 0.7275 - xent_loss: 207.6485 - mse_loss: 0.7274 - kl_loss: 3.7621e-05 - val_loss: 0.7277 - val_xent_loss: 207.6495 - val_mse_loss: 0.7276 - val_kl_loss: 3.8571e-05
#
# Epoch 00098: val_loss did not improve from 0.72591
# Epoch 99/100
# 40000/40000 [==============================] - 11s 268us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7499e-05 - val_loss: 0.7263 - val_xent_loss: 207.6468 - val_mse_loss: 0.7263 - val_kl_loss: 3.7864e-05
#
# Epoch 00099: val_loss did not improve from 0.72591
# Epoch 100/100
# 40000/40000 [==============================] - 11s 270us/step - loss: 0.7274 - xent_loss: 207.6484 - mse_loss: 0.7274 - kl_loss: 3.7652e-05 - val_loss: 0.7270 - val_xent_loss: 207.6482 - val_mse_loss: 0.7270 - val_kl_loss: 3.8500e-05
#
# Epoch 00100: val_loss did not improve from 0.72591

# %%
#load weights from file
vae.load_weights('drive/Seminar/models/vae_lstm_weights.hdf5')

# %%
# build a model to project inputs on the latent space
encoder = Model(x, z_mean)

# build a generator that can sample from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded = RepeatVector(timesteps)(decoder_input)
_h_decoded = decoder_h(_h_decoded)
_x_decoded_mean = decoder_mean(_h_decoded)
generator = Model(decoder_input, _x_decoded_mean)

# %%
#with open ('drive/Seminar/data/history_lstm.pickle', 'rb') as f:
    #history = pickle.load(f)

# summarize history for crossentropy loss
plt.plot(history.history['xent_loss'])
plt.plot(history.history['val_xent_loss'])
plt.title('crossentropy loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for mse loss
plt.plot(history.history['mse_loss'])
plt.plot(history.history['val_mse_loss'])
plt.title('mse loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for divergence loss
plt.plot(history.history['kl_loss'])
plt.plot(history.history['val_kl_loss'])
plt.title('divergence loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for total loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('total loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Generating Text From Latent Space

# %% [markdown]
# ### Save samples to file

# %%
# select sample and save to file

with open ('drive/Seminar/data/reviews_processed.pickle', 'rb') as f:
    data = pickle.load(f)
print("Total reviews: ", len(data))

data_concat = []
sample_size = 1000
for x in data[:sample_size]:
  data_concat.append(list(itertools.chain.from_iterable(x)))
  
data_array = np.array(data_concat)
print("Sample size: ", sample_size)

with open ('drive/Seminar/data/reviews_sample_lstm.pickle', 'wb') as f:
    pickle.dump(data_array,f)

    
# scale samples for encoding

with open ('drive/Seminar/data/scale_values.pickle', 'rb') as f:
    scale_values = pickle.load(f)
    
data_min = scale_values['min']
data_max = scale_values['max']

data_array_scaled = data_array
data_array_scaled = np.interp(data_array_scaled, (data_min, data_max), (0, 1))
data_array_scaled = data_array_scaled.reshape(-1,timesteps,original_dim)
# Out:
# Total reviews:  91798
# Sample size:  1000

# %%
# encode and decode samples

sent_encoded = encoder.predict(data_array_scaled, batch_size=500)

sent_decoded = generator.predict(sent_encoded)
sent_decoded = np.interp(sent_decoded, (0, 1), (data_min, data_max))
sent_decoded = sent_decoded.reshape(-1,timesteps*original_dim)

with open ('drive/Seminar/data/reviews_sample_decoded_lstm.pickle', 'wb') as f:
    pickle.dump(sent_decoded,f)

# %%
# generate new sentences

n_sentences = 1000
random = [np.random.normal(0., epsilon_std*0.4, latent_dim) for x in range(n_sentences)]
random = np.array(random).reshape(-1,latent_dim)
sent_generated = generator.predict(random)
sent_generated = np.interp(sent_generated, (0, 1), (data_min, data_max))
sent_generated = sent_generated.reshape(-1,timesteps*original_dim)

with open ('drive/Seminar/data/reviews_sample_generated_lstm.pickle', 'wb') as f:
    pickle.dump(sent_generated,f)

# %% [markdown]
# ### Print samples as strings

# %%
w2v = KeyedVectors.load_word2vec_format('drive/Seminar/data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
# load original, decoded and generated samples

with open ('drive/Seminar/data/reviews_sample_lstm.pickle', 'rb') as f:
    sample = pickle.load(f)
    
with open ('drive/Seminar/data/reviews_sample_decoded_lstm.pickle', 'rb') as f:
    sample_decoded = pickle.load(f)
    
with open ('drive/Seminar/data/reviews_sample_generated_lstm.pickle', 'rb') as f:
    sample_generated = pickle.load(f)

# %%
# input: original dimension sentence vector
# output: text

def print_sentence_with_w2v(sent_vect):
    word_sent = ''
    tocut = sent_vect
    for i in range (int(len(sent_vect)/300)):
        word_sent += w2v.most_similar(positive=[tocut[:300]], topn=1)[0][0]
        word_sent += ' '
        tocut = tocut[300:]
    print(word_sent)

# %%
# compare original and reconstructed sentences

for i in range(10):
  print_sentence_with_w2v(sample[i])
  print_sentence_with_w2v(sample_decoded[i])
  print()

# %%
# print generated sentences

for i in range(10):
  print_sentence_with_w2v(sample_generated[i])

# %% [markdown]
# ## Evaluating Anomaly Score

# %%
#load values for data scaling

with open ('drive/Seminar/data/scale_values_lstm.pickle', 'rb') as f:
    scale_values = pickle.load(f)
    
data_min = scale_values['min']
data_max = scale_values['max']

# %%
#load positive data (reviews)

with open ('drive/Seminar/data/reviews_processed_detection.pickle', 'rb') as f:
    pos_data = pickle.load(f)
print("Total reviews (positive data): ", len(pos_data))

pos_data_concat = []
for x in pos_data:
  pos_data_concat.append(list(itertools.chain.from_iterable(x)))
  
pos_data_array = np.array(pos_data_concat)
pos_data_array = np.interp(pos_data_array, (data_min, data_max), (0, 1))
pos_data_array = pos_data_array.reshape(-1,timesteps,original_dim)
pos_data_array.shape
# Out:
# Total reviews (positive data):  10000
# (10000, 10, 300)

# %%
pos_scores = {'loss': [], 'xent_loss': [], 'mse_loss': [], 'kl_loss': []}

for sample in pos_data_array:
  sample = sample.reshape(1,timesteps,original_dim)
  scores = vae.evaluate(sample, sample, batch_size=1, verbose=0)
  pos_scores['loss'].append(scores[0])
  pos_scores['xent_loss'].append(scores[1])
  pos_scores['mse_loss'].append(scores[2])
  pos_scores['kl_loss'].append(scores[3])

# %%
#load negative data (news headlines)

with open ('drive/Seminar/data/news_processed.pickle', 'rb') as f:
    neg_data = pickle.load(f)
print("Total news headlines (negative data): ", len(neg_data))

neg_data_concat = []
for x in neg_data:
  neg_data_concat.append(list(itertools.chain.from_iterable(x)))
  
neg_data_array = np.array(neg_data_concat)
neg_data_array = np.interp(neg_data_array, (data_min, data_max), (0, 1))
neg_data_array = neg_data_array.reshape(-1,timesteps,original_dim)
neg_data_array.shape
# Out:
# Total news headlines (negative data):  10000
# (10000, 10, 300)

# %%
neg_scores = {'loss': [], 'xent_loss': [], 'mse_loss': [], 'kl_loss': []}

for sample in neg_data_array:
  sample = sample.reshape(1,timesteps,original_dim)
  scores = vae.evaluate(sample, sample, batch_size=1, verbose=0)
  neg_scores['loss'].append(scores[0])
  neg_scores['xent_loss'].append(scores[1])
  neg_scores['mse_loss'].append(scores[2])
  neg_scores['kl_loss'].append(scores[3])

# %%
for score in ['loss', 'xent_loss', 'mse_loss', 'kl_loss']:
  plt.figure()
  ax1 = sns.distplot(pos_scores[score] , hist = False, kde = True,
                   kde_kws = {'linewidth': 1, 'shade':True}, label='reviews',color="blue")
  ax2 = sns.distplot(neg_scores[score] , hist = False, kde = True,
                   kde_kws = {'linewidth': 1, 'shade':True}, label='news headlines', color= "red")



  plt.title('Density function of '+score+' values')
  plt.xlabel(score)
  plt.ylabel('Density')
  plt.legend()

# %%
for score in ['loss', 'xent_loss', 'mse_loss', 'kl_loss']:
  
  y_true_pos = np.ones(len(pos_scores[score]))
  y_true_neg = np.zeros(len(neg_scores[score]))
                        
  y_true = np.concatenate((y_true_pos, y_true_neg))
  y_pred = np.concatenate((pos_scores[score], neg_scores[score]))

  fpr, tpr, thresholds = skl.roc_curve(y_true, y_pred, pos_label=0)
  roc_auc = skl.auc(fpr, tpr)  
  
  plt.figure()
  lw = 2
  plt.plot(fpr, tpr, color='blue',
           lw=lw, label='ROC curve (area = %0.4f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='red', lw=lw, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver operating characteristic for '+score)
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## Regular Reviews vs Food Reviews

# %%
#load semi negative data (food reviews)

with open ('drive/Seminar/data/food_reviews_processed.pickle', 'rb') as f:
    semi_data = pickle.load(f)
print("Total food reviews (semi negative data): ", len(semi_data))

semi_data_concat = []
for x in semi_data:
  semi_data_concat.append(list(itertools.chain.from_iterable(x)))
  
semi_data_array = np.array(semi_data_concat)
semi_data_array = np.interp(semi_data_array, (data_min, data_max), (0, 1))
semi_data_array = semi_data_array.reshape(-1,timesteps,original_dim)
semi_data_array.shape
# Out:
# Total food reviews (semi negative data):  10000
# (10000, 10, 300)

# %%
semi_scores = {'loss': [], 'xent_loss': [], 'mse_loss': [], 'kl_loss': []}

for sample in semi_data_array:
  sample = sample.reshape(1,timesteps,original_dim)
  scores = vae.evaluate(sample, sample, batch_size=1, verbose=0)
  semi_scores['loss'].append(scores[0])
  semi_scores['xent_loss'].append(scores[1])
  semi_scores['mse_loss'].append(scores[2])
  semi_scores['kl_loss'].append(scores[3])

# %%
for score in ['loss', 'xent_loss', 'mse_loss', 'kl_loss']:
  plt.figure()
  ax1 = sns.distplot(pos_scores[score] , hist = False, kde = True,
                   kde_kws = {'linewidth': 1, 'shade':True}, label='general reviews',color="blue")
  ax2 = sns.distplot(semi_scores[score] , hist = False, kde = True,
                   kde_kws = {'linewidth': 1, 'shade':True}, label='food reviews', color= "red")



  plt.title('Density function of '+score+' values')
  plt.xlabel(score)
  plt.ylabel('Density')
  plt.legend()

# %%
for score in ['loss', 'xent_loss', 'mse_loss', 'kl_loss']:
  
  y_true_pos = np.ones(len(pos_scores[score]))
  y_true_semi = np.zeros(len(semi_scores[score]))
                        
  y_true = np.concatenate((y_true_pos, y_true_semi))
  y_pred = np.concatenate((pos_scores[score], semi_scores[score]))

  fpr, tpr, thresholds = skl.roc_curve(y_true, y_pred, pos_label=0)
  roc_auc = skl.auc(fpr, tpr)  
  
  plt.figure()
  lw = 2
  plt.plot(fpr, tpr, color='blue',
           lw=lw, label='ROC curve (area = %0.4f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='red', lw=lw, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver operating characteristic for '+score)
  plt.legend(loc="lower right")
  plt.show()
